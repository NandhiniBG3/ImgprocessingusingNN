# %%
import cv2
import base64
import numpy as np
import scipy
from scipy.misc import imread
import pickle
import random
import os
import matplotlib.pyplot as plt

# Feature extractor
def extract_features(image_path, vector_size=32):
    image = imread(image_path, mode="RGB")
    try:
        # Using KAZE, cause SIFT, ORB and other was moved to additional module
        # which is adding addtional pain during install
        alg = cv2.KAZE_create()
        # Dinding image keypoints
        kps = alg.detect(image)
        # Getting first 32 of them. 
        # Number of keypoints is varies depend on image size and color pallet
        # Sorting them based on keypoint response value(bigger is better)
        kps = sorted(kps, key=lambda x: -x.response)[:vector_size]
        # computing descriptors vector
        kps, dsc = alg.compute(image, kps)
        # Flatten all of them in one big vector - our feature vector
        dsc = dsc.flatten()
        # Making descriptor of same size
        # Descriptor vector size is 64
        needed_size = (vector_size * 64)
        if dsc.size < needed_size:
            # if we have less the 32 descriptors then just adding zeros at the
            # end of our feature vector
            dsc = np.concatenate([dsc, np.zeros(needed_size - dsc.size)])
    except cv2.error as e:
        print ('Error: ', e)
        return None

    return dsc


def batch_extractor(images_path, pickled_db_path="features.pck"):
    files = [os.path.join(images_path, p) for p in sorted(os.listdir(images_path))]

    result = {}
    for f in files:
        print ('Extracting features from image %s' % f)
        name = f.split('/')[-1].lower()
        result[name] = extract_features(f)
    
    # saving all our feature vectors in pickled file
    with open(pickled_db_path, 'w') as fp:
            pickle.dump(result, fp)

# %%
class Matcher(object):

    def __init__(self, pickled_db_path="features.pck"):
        with open(pickled_db_path) as fp:
            self.data = pickle.load(fp)
        self.names = []
        self.matrix = []
        for k, v in self.data.iteritems():
            self.names.append(k)
            self.matrix.append(v)
        self.matrix = np.array(self.matrix)
        self.names = np.array(self.names)

    def cos_cdist(self, vector):
        # getting cosine distance between search image and images database
        v = vector.reshape(1, -1)
        return scipy.spatial.distance.cdist(self.matrix, v, 'cosine').reshape(-1)

    def match(self, image_path, topn=5):
        features = extract_features(image_path)
        img_distances = self.cos_cdist(features)
        # getting top 5 records
        nearest_ids = np.argsort(img_distances)[:topn].tolist()
        nearest_img_paths = self.names[nearest_ids].tolist()

        return nearest_img_paths, img_distances[nearest_ids].tolist()

# %%
def show_img(path):
    img = imread(path, mode="RGB")
    plt.imshow(img)
    plt.show()
    
def run():
    images_path = 'D:\\rib resize\\'
    files = [os.path.join(images_path, p) for p in sorted(os.listdir(images_path))]
    # getting 3 random images 
    sample = random.sample(files, 3)
    
    batch_extractor(images_path)

    ma = Matcher('features.pck')
    
    for s in sample:
        print ('Query image ==========================================')
        show_img(s)
        names, match = ma.match(s, topn=3)
        print ('Result images ========================================')
        for i in range(3):
            # we got cosine distance, less cosine distance between vectors
            # more they similar, thus we subtruct it from 1 to get match value
            print ('Match %s' % (1-match[i]))
            show_img(os.path.join(images_path, names[i]))

run()
# Out:
# Extracting features from image D:\rib resize\0.png
# C:\Users\new\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   del sys.path[0]
# Extracting features from image D:\rib resize\1.png
# Extracting features from image D:\rib resize\10.png
# Extracting features from image D:\rib resize\100.png
# Extracting features from image D:\rib resize\101.png
# Extracting features from image D:\rib resize\102.png
# Extracting features from image D:\rib resize\103.png
# Extracting features from image D:\rib resize\104.png
# Extracting features from image D:\rib resize\105.png
# Extracting features from image D:\rib resize\106.png
# Extracting features from image D:\rib resize\107.png
# Extracting features from image D:\rib resize\108.png
# Extracting features from image D:\rib resize\109.png
# Extracting features from image D:\rib resize\11.png
# Extracting features from image D:\rib resize\110.png
# Extracting features from image D:\rib resize\111.png
# Extracting features from image D:\rib resize\112.png
# Extracting features from image D:\rib resize\113.png
# Extracting features from image D:\rib resize\114.png
# Extracting features from image D:\rib resize\115.png
# Extracting features from image D:\rib resize\116.png
# Extracting features from image D:\rib resize\117.png
# Extracting features from image D:\rib resize\118.png
# Extracting features from image D:\rib resize\119.png
# Extracting features from image D:\rib resize\12.png
# Extracting features from image D:\rib resize\120.png
# Extracting features from image D:\rib resize\121.png
# Extracting features from image D:\rib resize\122.png
# Extracting features from image D:\rib resize\123.png
# Extracting features from image D:\rib resize\124.png
# Extracting features from image D:\rib resize\125.png
# Extracting features from image D:\rib resize\126.png
# Extracting features from image D:\rib resize\127.png
# Extracting features from image D:\rib resize\128.png
# Extracting features from image D:\rib resize\129.png
# Extracting features from image D:\rib resize\13.png
# Extracting features from image D:\rib resize\130.png
# Extracting features from image D:\rib resize\131.png
# Extracting features from image D:\rib resize\132.png
# Extracting features from image D:\rib resize\133.png
# Extracting features from image D:\rib resize\134.png
# Extracting features from image D:\rib resize\135.png
# Extracting features from image D:\rib resize\136.png
# Extracting features from image D:\rib resize\137.png
# Extracting features from image D:\rib resize\138.png
# Extracting features from image D:\rib resize\139.png
# Extracting features from image D:\rib resize\14.png
# Extracting features from image D:\rib resize\140.png
# Extracting features from image D:\rib resize\141.png
# Extracting features from image D:\rib resize\142.png
# Extracting features from image D:\rib resize\143.png
# Extracting features from image D:\rib resize\144.png
# Extracting features from image D:\rib resize\145.png
# Extracting features from image D:\rib resize\146.png
# Extracting features from image D:\rib resize\147.png
# Extracting features from image D:\rib resize\148.png
# Extracting features from image D:\rib resize\149.png
# Extracting features from image D:\rib resize\15.png
# Extracting features from image D:\rib resize\150.png
# Extracting features from image D:\rib resize\151.png
# Extracting features from image D:\rib resize\152.png
# Extracting features from image D:\rib resize\153.png
# Extracting features from image D:\rib resize\154.png
# Extracting features from image D:\rib resize\155.png
# Extracting features from image D:\rib resize\156.png
# Extracting features from image D:\rib resize\157.png
# Extracting features from image D:\rib resize\158.png
# Extracting features from image D:\rib resize\159.png
# Extracting features from image D:\rib resize\16.png
# Extracting features from image D:\rib resize\160.png
# Extracting features from image D:\rib resize\161.png
# Extracting features from image D:\rib resize\162.png
# Extracting features from image D:\rib resize\163.png
# Extracting features from image D:\rib resize\164.png
# Extracting features from image D:\rib resize\165.png
# Extracting features from image D:\rib resize\166.png
# Extracting features from image D:\rib resize\167.png
# Extracting features from image D:\rib resize\168.png
# Extracting features from image D:\rib resize\169.png
# Extracting features from image D:\rib resize\17.png
# Extracting features from image D:\rib resize\170.png
# Extracting features from image D:\rib resize\171.png
# Extracting features from image D:\rib resize\172.png
# Extracting features from image D:\rib resize\173.png
# Extracting features from image D:\rib resize\174.png
# Extracting features from image D:\rib resize\175.png
# Extracting features from image D:\rib resize\176.png
# Extracting features from image D:\rib resize\177.png
# Extracting features from image D:\rib resize\178.png
# Extracting features from image D:\rib resize\179.png
# Extracting features from image D:\rib resize\18.png
# Extracting features from image D:\rib resize\180.png
# Extracting features from image D:\rib resize\181.png
# Extracting features from image D:\rib resize\182.png
# Extracting features from image D:\rib resize\183.png
# Extracting features from image D:\rib resize\184.png
# Extracting features from image D:\rib resize\185.png
# Extracting features from image D:\rib resize\186.png
# Extracting features from image D:\rib resize\187.png
# Extracting features from image D:\rib resize\188.png
# Extracting features from image D:\rib resize\189.png
# Extracting features from image D:\rib resize\19.png
# Extracting features from image D:\rib resize\190.png
# Extracting features from image D:\rib resize\191.png
# Extracting features from image D:\rib resize\192.png
# Extracting features from image D:\rib resize\193.png
# Extracting features from image D:\rib resize\194.png
# Extracting features from image D:\rib resize\195.png
# Extracting features from image D:\rib resize\196.png
# Extracting features from image D:\rib resize\197.png
# Extracting features from image D:\rib resize\198.png
# Extracting features from image D:\rib resize\199.png
# Extracting features from image D:\rib resize\2.png
# Extracting features from image D:\rib resize\20.png
# Extracting features from image D:\rib resize\200.png
# Extracting features from image D:\rib resize\201.png
# Extracting features from image D:\rib resize\202.png
# Extracting features from image D:\rib resize\203.png
# Extracting features from image D:\rib resize\204.png
# Extracting features from image D:\rib resize\205.png
# Extracting features from image D:\rib resize\206.png
# Extracting features from image D:\rib resize\207.png
# Extracting features from image D:\rib resize\208.png
# Extracting features from image D:\rib resize\209.png
# Extracting features from image D:\rib resize\21.png
# Extracting features from image D:\rib resize\210.png
# Extracting features from image D:\rib resize\211.png
# Extracting features from image D:\rib resize\212.png
# Extracting features from image D:\rib resize\213.png
# Extracting features from image D:\rib resize\214.png
# Extracting features from image D:\rib resize\215.png
# Extracting features from image D:\rib resize\216.png
# Extracting features from image D:\rib resize\217.png
# Extracting features from image D:\rib resize\218.png
# Extracting features from image D:\rib resize\219.png
# Extracting features from image D:\rib resize\22.png
# Extracting features from image D:\rib resize\220.png
# Extracting features from image D:\rib resize\221.png
# Extracting features from image D:\rib resize\222.png
# Extracting features from image D:\rib resize\223.png
# Extracting features from image D:\rib resize\224.png
# Extracting features from image D:\rib resize\225.png
# Extracting features from image D:\rib resize\226.png
# Extracting features from image D:\rib resize\227.png
# Extracting features from image D:\rib resize\228.png
# Extracting features from image D:\rib resize\229.png
# Extracting features from image D:\rib resize\23.png
# Extracting features from image D:\rib resize\230.png
# Extracting features from image D:\rib resize\231.png
# Extracting features from image D:\rib resize\232.png
# Extracting features from image D:\rib resize\233.png
# Extracting features from image D:\rib resize\234.png
# Extracting features from image D:\rib resize\235.png
# Extracting features from image D:\rib resize\236.png
# Extracting features from image D:\rib resize\237.png
# Extracting features from image D:\rib resize\238.png
# Extracting features from image D:\rib resize\239.png
# Extracting features from image D:\rib resize\24.png
# Extracting features from image D:\rib resize\240.png
# Extracting features from image D:\rib resize\241.png
# Extracting features from image D:\rib resize\242.png
# Extracting features from image D:\rib resize\243.png
# Extracting features from image D:\rib resize\244.png
# Extracting features from image D:\rib resize\245.png
# Extracting features from image D:\rib resize\25.png
# Extracting features from image D:\rib resize\26.png
# Extracting features from image D:\rib resize\27.png
# Extracting features from image D:\rib resize\28.png
# Extracting features from image D:\rib resize\29.png
# Extracting features from image D:\rib resize\3.png
# Extracting features from image D:\rib resize\30.png
# Extracting features from image D:\rib resize\31.png
# Extracting features from image D:\rib resize\32.png
# Extracting features from image D:\rib resize\33.png
# Extracting features from image D:\rib resize\34.png
# Extracting features from image D:\rib resize\35.png
# Extracting features from image D:\rib resize\36.png
# Extracting features from image D:\rib resize\37.png
# Extracting features from image D:\rib resize\38.png
# Extracting features from image D:\rib resize\39.png
# Extracting features from image D:\rib resize\4.png
# Extracting features from image D:\rib resize\40.png
# Extracting features from image D:\rib resize\41.png
# Extracting features from image D:\rib resize\42.png
# Extracting features from image D:\rib resize\43.png
# Extracting features from image D:\rib resize\44.png
# Extracting features from image D:\rib resize\45.png
# Extracting features from image D:\rib resize\46.png
# Extracting features from image D:\rib resize\47.png
# Extracting features from image D:\rib resize\48.png
# Extracting features from image D:\rib resize\49.png
# Extracting features from image D:\rib resize\5.png
# Extracting features from image D:\rib resize\50.png
# Extracting features from image D:\rib resize\51.png
# Extracting features from image D:\rib resize\52.png
# Extracting features from image D:\rib resize\53.png
# Extracting features from image D:\rib resize\54.png
# Extracting features from image D:\rib resize\55.png
# Extracting features from image D:\rib resize\56.png
# Extracting features from image D:\rib resize\57.png
# Extracting features from image D:\rib resize\58.png
# Extracting features from image D:\rib resize\59.png
# Extracting features from image D:\rib resize\6.png
# Extracting features from image D:\rib resize\60.png
# Extracting features from image D:\rib resize\61.png
# Extracting features from image D:\rib resize\62.png
# Extracting features from image D:\rib resize\63.png
# Extracting features from image D:\rib resize\64.png
# Extracting features from image D:\rib resize\65.png
# Extracting features from image D:\rib resize\66.png
# Extracting features from image D:\rib resize\67.png
# Extracting features from image D:\rib resize\68.png
# Extracting features from image D:\rib resize\69.png
# Extracting features from image D:\rib resize\7.png
# Extracting features from image D:\rib resize\70.png
# Extracting features from image D:\rib resize\71.png
# Extracting features from image D:\rib resize\72.png
# Extracting features from image D:\rib resize\73.png
# Extracting features from image D:\rib resize\74.png
# Extracting features from image D:\rib resize\75.png
# Extracting features from image D:\rib resize\76.png
# Extracting features from image D:\rib resize\77.png
# Extracting features from image D:\rib resize\78.png
# Extracting features from image D:\rib resize\79.png
# Extracting features from image D:\rib resize\8.png
# Extracting features from image D:\rib resize\80.png
# Extracting features from image D:\rib resize\81.png
# Extracting features from image D:\rib resize\82.png
# Extracting features from image D:\rib resize\83.png
# Extracting features from image D:\rib resize\84.png
# Extracting features from image D:\rib resize\85.png
# Extracting features from image D:\rib resize\86.png
# Extracting features from image D:\rib resize\87.png
# Extracting features from image D:\rib resize\88.png
# Extracting features from image D:\rib resize\89.png
# Extracting features from image D:\rib resize\9.png
# Extracting features from image D:\rib resize\90.png
# Extracting features from image D:\rib resize\91.png
# Extracting features from image D:\rib resize\92.png
# Extracting features from image D:\rib resize\93.png
# Extracting features from image D:\rib resize\94.png
# Extracting features from image D:\rib resize\95.png
# Extracting features from image D:\rib resize\96.png
# Extracting features from image D:\rib resize\97.png
# Extracting features from image D:\rib resize\98.png
# Extracting features from image D:\rib resize\99.png
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-987b5135a97e> in <module>
#      25             show_img(os.path.join(images_path, names[i]))
#      26
# ---> 27 run()
#
# <ipython-input-3-987b5135a97e> in run()
#      10     sample = random.sample(files, 3)
#      11
# ---> 12     batch_extractor(images_path)
#      13
#      14     ma = Matcher('features.pck')
#
# <ipython-input-1-3a0c0529c462> in batch_extractor(images_path, pickled_db_path)
#      51     # saving all our feature vectors in pickled file
#      52     with open(pickled_db_path, 'w') as fp:
# ---> 53             pickle.dump(result, fp)
#
# TypeError: write() argument must be str, not bytes
